# %% [markdown]
# <a href="https://colab.research.google.com/github/vanshikaml04/DEEP-LEARNING/blob/main/MISSING_DATA_PART_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/content/titanic.csv')

# %%
df.head()
# Out:
#   Cabin            Ticket number  Survived
# 0   NaN         A/5 21171      5         0
# 1   C85          PC 17599      3         1
# 2   NaN  STON/O2. 3101282      6         1
# 3  C123            113803      3         1
# 4   NaN            373450      A         0

# %%
df.shape
# Out:
# (891, 4)

# %%
categorical_cols = df.select_dtypes(include=['object']).columns

# %%
for col in categorical_cols:
  print(col)
# Out:
# Cabin
# Ticket
# number

# %%
df.isnull() # shows true/false of missing values
# Out:
#      Cabin  Ticket  number  Survived
# 0     True   False   False     False
# 1    False   False   False     False
# 2     True   False   False     False
# 3    False   False   False     False
# 4     True   False   False     False
# ..     ...     ...     ...       ...
# 886   True   False   False     False
# 887  False   False   False     False
# 888   True   False   False     False
# 889  False   False   False     False
# 890   True   False   False     False
#
# [891 rows x 4 columns]

# %%
df.isnull().sum() # count the missing values
# Out:
# Cabin       687
# Ticket        0
# number        0
# Survived      0
# dtype: int64

# %%
df["Cabin"].fillna("Unknown", inplace=True)

# %%
df.head()
# Out:
#       Cabin            Ticket number  Survived
# 0  Unknonwn         A/5 21171      5         0
# 1       C85          PC 17599      3         1
# 2  Unknonwn  STON/O2. 3101282      6         1
# 3      C123            113803      3         1
# 4  Unknonwn            373450      A         0

# %%
#If a column has >50% missing, you might drop it entirely.
